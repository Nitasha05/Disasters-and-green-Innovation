# %%
import pandas as pd
import numpy as np
import re
from itertools import chain
from pathlib import Path

# %% [markdown]
# #### Map file names

# %%
emdat_patsat_names = {'1_ExTemp':'Extreme temperature ', '3_Storm':'Storm', '4_Flood':'Flood', '5_Landslide':'Landslide', '7_Drought':'Drought', '9_Wildfire':'Wildfire'}

# %% [markdown]
# #### Map countries

# %%
countries = []
for c in emdat_patsat_names.keys():
    df = pd.read_csv('/Volumes/NJ_4TB/PATSAT/MyFiles/' + c + '_panel.csv', skipinitialspace=True, header=0)
    countries = countries + pd.unique(df['country']).tolist()
patsat_unique_countries = list(set(countries))
print("# unique countries in PATSAT : ", len(patsat_unique_countries))

# %%
countries = []
for c in emdat_patsat_names.values():
    df = pd.read_csv(c + '_EMDAT_panel.csv', skipinitialspace=True, header=0)
    countries = countries + pd.unique(df['country']).tolist()
emdat_unique_countries = list(set(countries))
print("# unique countries in EMDAT : ", len(emdat_unique_countries))

# %%
patsat_unique_countries

# %%
r = re.compile(".*saud", re.IGNORECASE)
print(list(filter(r.match, emdat_unique_countries)))

# %%
emdat_patsat_countries={ 'KR':'Korea (the Republic of)',
                         'MX':'Mexico',
                         'EG':'Egypt',
                         'JP':'Japan',
                         'NO':'Norway',
                         'CA':'Canada',
                         'SI':'Slovenia',
                         'DK':'Denmark',
                         'TH':'Thailand',
                         'FI':'Finland',
                         'HU':'Hungary',
                         'IS':'Iceland',
                         'IN':'India',
                         'US':'United States of America (the)',
                         'CZ':['Czech Republic (the)', 'Czechoslovakia','Slovakia'],
                         'CL':'Chile',
                         'PL':'Poland',
                         'LV':'Latvia',
                         'KY':'Cayman Islands (the)',
                         'PH':'Philippines (the)',
                         'DE':['Germany Dem Rep', 'Germany', 'Germany Fed Rep'],#also DD
                         'SG':'Singapore',
                         'CH':'Switzerland',
                         'LT':'Lithuania',
                         'CY':'Cyprus',
                         'RU':'Russian Federation (the)',
                         'UA':'Ukraine',
                         'IT':'Italy',
                         'AU':'Australia',
                         'NZ':'New Zealand',
                         'BE':'Belgium',
                         'QA':'Qatar',
                         'MY':'Malaysia',
                         'BM':'Bermuda',
                         'AT':'Austria',
                         'SU':'Soviet Union',
                         'GR':'Greece',
                         'MT':'Malta',
                         'IE':'Ireland',
                         'TR':'Turkey',
                         'ES':'Spain',
                         'NL':'Netherlands (the)',
                         'IL':'Israel',
                         'MA':'Morocco',
                         'AE':'United Arab Emirates (the)',
                         'CU':'Cuba',
                         'SE':'Sweden',
                         'CN':'China',
                         'FR':'France',
                         'LU':'Luxembourg',
                         'PA':'Panama',
                         'BG':'Bulgaria',
                         'ZA':'South Africa',
                         'TW':'Taiwan (Province of China)',
                         'AR':'Argentina',
                         'BR':'Brazil',
                         'GB':'United Kingdom of Great Britain and Northern Ireland (the)',
                         'SA':'Saudi Arabia'
                       }

# %%
emdat_patsat_map = {}
for key, val in emdat_patsat_countries.items():
    if key == 'CZ' or key == 'DE':
        for i, coun in enumerate(val):
            emdat_patsat_map[coun] = key + str(i)
    else:
        emdat_patsat_map[val] = key
emdat_patsat_map

# %% [markdown]
# ### Combine PATSAT, EMDAT
# #### also, combine DE and DD in PATSAT

# %%
# for patsat, emdat in emdat_patsat_names.items():
#     df_patsat =  pd.read_csv('/Volumes/NJ_4TB/PATSAT/MyFiles/' + patsat + '_panel.csv', skipinitialspace=True, header=0)
#     df_emdat = pd.read_csv(emdat + '_EMDAT_panel.csv', skipinitialspace=True, header=0)
#     ## combine DE with DD
#     if np.where(df_patsat['country'] == 'DD')[0].size>0:
#         for year in range( 1985,  2020 + 1):
#             dd_year = np.where((df_patsat['year'] == year) & (df_patsat['country'] == 'DD'))
#             if dd_year[0].size>0:
#                 dd = dd_year[0][0]
#                 de = np.where((df_patsat['year'] == year) & (df_patsat['country'] == 'DE') )[0][0]
#                 df_patsat.at[de,'total_count'] += df_patsat.at[dd,'total_count']
#                 df_patsat.at[de,'granted_count'] +=  df_patsat.at[dd,'granted_count']
#                 df_patsat.at[de,'granted_family_ge_2_count'] += df_patsat.at[dd,'granted_family_ge_2_count']
#     df_patsat.drop(df_patsat[df_patsat['country'] == 'LI'].index, inplace=True)
#     df_patsat.drop(df_patsat[df_patsat['country'] == 'VG'].index, inplace=True)
#     df_patsat.drop(df_patsat[df_patsat['country'] == 'DD'].index, inplace=True)
#     df_patsat.drop(df_patsat[df_patsat['country'] == 'FO'].index, inplace=True)
#     df_patsat["total_deaths"] = 0
#     df_patsat["total_affected"] = 0
#     df_patsat["total_damages_adj"] = 0
#     for country in pd.unique(df_patsat.country):
#         if country == 'DE' or country == 'CZ':
#             emdat_countries = emdat_patsat_countries[country]
#         else:
#             emdat_countries = [emdat_patsat_countries[country]]
        
#         for ec in emdat_countries:
#             for year in range( 1985,  2020 + 1):
#                 pt_year = np.where((df_patsat['year'] == year) & (df_patsat['country'] == country))
#                 if pt_year[0].size>0:
#                     pt = pt_year[0][0]
#                     em = np.where((df_emdat['year'] == year) & (df_emdat['country'] == ec) )[0][0]
#                     df_patsat.at[pt,'total_deaths'] = df_emdat.at[em,'total_deaths']
#                     df_patsat.at[pt,'total_affected'] =  df_emdat.at[em,'total_affected']
#                     df_patsat.at[pt,'total_damages_adj'] = df_emdat.at[em,'total_damages_adj']
#     if patsat=='1_ExTemp':
#         print(pd.unique(df_patsat['country']))
        
#     print('Combined ' + patsat)    
#     df_patsat.to_csv(patsat + '_panel_combined.csv', encoding='utf-8', index=False)

# %%
for patsat, emdat in emdat_patsat_names.items():
    df_patsat =  pd.read_csv('/Volumes/NJ_4TB/PATSAT/MyFiles/' + patsat + '_panel.csv', skipinitialspace=True, header=0)
    df_emdat = pd.read_csv(emdat + '_EMDAT_panel.csv', skipinitialspace=True, header=0)
    if np.where(df_patsat['country'] == 'DD')[0].size>0:
        for year in range( 1985,  2020 + 1):
            dd_year = np.where((df_patsat['year'] == year) & (df_patsat['country'] == 'DD'))
            if dd_year[0].size>0:
                dd = dd_year[0][0]
                de = np.where((df_patsat['year'] == year) & (df_patsat['country'] == 'DE') )[0][0]
                df_patsat.at[de,'total_count'] += df_patsat.at[dd,'total_count']
                df_patsat.at[de,'granted_count'] +=  df_patsat.at[dd,'granted_count']
                df_patsat.at[de,'granted_family_ge_2_count'] += df_patsat.at[dd,'granted_family_ge_2_count']
                df_patsat.at[de,'K_stock'] += df_patsat.at[dd,'K_stock']
    df_patsat.drop(df_patsat[df_patsat['country'] == 'LI'].index, inplace=True)
    df_patsat.drop(df_patsat[df_patsat['country'] == 'VG'].index, inplace=True)
    df_patsat.drop(df_patsat[df_patsat['country'] == 'DD'].index, inplace=True)
    df_patsat.drop(df_patsat[df_patsat['country'] == 'FO'].index, inplace=True)
    df_emdat['country'] = df_emdat['country'].map(emdat_patsat_map).fillna(df_emdat['country'])
    de_cz_emdat_list=[]

    for year in range(1985,2020+1):
        deaths = 0
        damage = 0
        affected = 0
        for country in ['DE0','DE1','DE2']:
            deaths += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_deaths'].to_numpy()[0]
            damage += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_damages_adj'].to_numpy()[0]
            affected += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_affected'].to_numpy()[0]
        de_cz_emdat_list.append({'country':country[:2],'year':year,'total_deaths':deaths,'total_damages_adj':damage,'total_affected':affected})

    for year in range(1985,2020+1):
        deaths = 0
        damage = 0
        affected = 0
        for country in ['CZ0','CZ1','CZ2']:
            deaths += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_deaths'].to_numpy()[0]
            damage += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_damages_adj'].to_numpy()[0]
            affected += df_emdat[(df_emdat['country']==country) & (df_emdat['year']==year)]['total_affected'].to_numpy()[0]
        de_cz_emdat_list.append({'country':country[:2],'year':year,'total_deaths':deaths,'total_damages_adj':damage,'total_affected':affected})

    df_de_cz = pd.DataFrame.from_records(de_cz_emdat_list)
    df_emdat = pd.concat([df_de_cz,df_emdat])
    df_combined = df_patsat.merge(df_emdat,on=['country','year'], how='inner')
    df_combined.to_csv(patsat + '_panel_combined.csv', encoding='utf-8', index=False)
    print('Combined ' + patsat)

# %% [markdown]
# ### Combine green technologies PATSAT data with the combined data above

# %%
Categories = ['Build','Sequester', 'ICT', 'Geo', 'Hydro', 'Ocean', 'Solar-T', 'PV', 'Thermal-PV', 'Wind', 'Combust', 'Fusion', 'Fission', 'Electric', 'Biofuel', 'Waste', 'Store- B', 'Store - C', 'Store- T', 'Store- M', 'Hydrogen', 'Processing', 'Transport', 'Wastewater', 'SmrtGrds', 'Nuclear', 'Non-Fossil', 'Enable',  'Other-1', 'Other-3']#, 'Other-5','Other-6', 'Other-4']
df_controls =pd.read_csv('controls_processed.csv', skipinitialspace=True, header=0)
for category in Categories:
    print("Now processing: "+ category)
    try:
        df_cat = pd.read_csv('/Volumes/NJ_4TB/PATSAT/MyFiles/' + category + '_panel.csv', skipinitialspace=True, header=0)
    except pd.errors.EmptyDataError:
        df_cat = pd.DataFrame()
    if df_cat.empty:
        print('Skipped '+ category)
        continue
    if np.where(df_cat['country'] == 'DD')[0].size>0:
        for year in range( 1985,  2020 + 1):
            dd_year = np.where((df_cat['year'] == year) & (df_cat['country'] == 'DD'))
            if dd_year[0].size>0:
                dd = dd_year[0][0]
                de = np.where((df_cat['year'] == year) & (df_cat['country'] == 'DE') )[0][0]
                df_cat.at[de,'total_count'] += df_cat.at[dd,'total_count']
                df_cat.at[de,'granted_count'] +=  df_cat.at[dd,'granted_count']
                df_cat.at[de,'granted_family_ge_2_count'] += df_cat.at[dd,'granted_family_ge_2_count']
                df_cat.at[de,'K_stock'] += df_cat.at[dd,'K_stock']
    df_cat.drop(df_cat[df_cat['country'] == 'LI'].index, inplace=True)
    df_cat.drop(df_cat[df_cat['country'] == 'VG'].index, inplace=True)
    df_cat.drop(df_cat[df_cat['country'] == 'DD'].index, inplace=True)
    df_cat.drop(df_cat[df_cat['country'] == 'FO'].index, inplace=True)
    df_cat = pd.concat([pd.get_dummies(df_cat['year']), df_cat],axis=1)
    df_cat.loc[:, 'K_stock'] = np.log(1 + df_cat['K_stock'])
    df_cat.rename(columns={'total_count':category+'_total_count', 'granted_count':category +'_granted_count', 'granted_family_ge_2_count':category+'_granted_family_ge_2_count', 'K_stock':category+'_K_stock'}, inplace=True)
    df_cat = df_cat.merge(df_controls, on=['country','year'], how='left')#NaNs if controls are not present 
    for adaptive in emdat_patsat_names.keys():        
        df_adapt = pd.read_csv(adaptive + '_panel_combined.csv', skipinitialspace=True, header=0)
        df_adapt.loc[:, 'K_stock'] = np.log(1 + df_adapt['K_stock'])
        df_adapt.rename(columns={'total_count':adaptive+'_total_count', 'granted_count':adaptive+'_granted_count', 'granted_family_ge_2_count':adaptive+'_granted_family_ge_2_count', 'K_stock':adaptive+'_K_stock'}, inplace=True)
        df_final=df_cat.merge(df_adapt, on=['country','year'], how='inner')
        df_final.loc[:, 'gdp_per_capita'] = np.log(df_final['gdp_per_capita'])
        df_final.loc[:, 'control_total_patents'] = np.log(df_final['control_total_patents'])
        df_final.drop(df_final[df_final['year'] >2018].index, inplace=True)
        df_final.drop(labels =2019, axis =1, inplace=True, errors='ignore')
        df_final.drop(labels =2020, axis =1, inplace=True, errors='ignore')
        #  print('Combined ' + category + ' with '+ adaptive)    
        directory = 'Adaptive_Mitigative/'# + category + '_' + adaptive + '/'
        Path(directory).mkdir(parents=True, exist_ok=True)
        df_final.to_csv( directory + category + '_' + adaptive + '_panel_combined.csv', encoding='utf-8', index=False)

# %%
#extracting chosen country samples
import pandas as pd
import numpy as np
Categories = ['Build','Sequester', 'ICT', 'Geo', 'Hydro', 'Ocean', 'Solar-T', 'PV', 'Thermal-PV', 'Wind', 'Combust', 'Fusion', 'Fission', 'Electric', 'Biofuel', 'Waste', 'Store- B', 'Store - C', 'Store- T', 'Store- M', 'Hydrogen', 'Processing', 'Transport', 'Wastewater', 'SmrtGrds', 'Nuclear', 'Non-Fossil', 'Enable',  'Other-1', 'Other-3']#, 'Other-5','Other-6', 'Other-4']
emdat_patsat_names = {'1_ExTemp':'Extreme temperature ', '3_Storm':'Storm', '4_Flood':'Flood', '5_Landslide':'Landslide', '7_Drought':'Drought', '9_Wildfire':'Wildfire'}
countries = {'Country': ['KR','MX','EG','JP','NO','CA','SI','DK','TH','FI','HU','IS','IN','US','CZ','CL','PL','LV','KY','PH','DE','SG','CH','LT', 'CY',                          
'RU','UA','IT','AU','NZ','BE','QA','MY','BM','AT','SU','GR','MT','IE','TR','ES','NL','IL','MA','AE','CU', 'SE',                          
'CN','FR','LU','PA','BG','ZA','TW','AR','BR','GB','SA']}                         
sample_list = pd.DataFrame(countries)
for a in emdat_patsat_names:
    for c in Categories:
        df = pd.read_csv('/Volumes/NJ_4TB/Final/Adaptive_Mitigative/'+ c + '_'+ a + '_panel_combined.csv', skipinitialspace=True, header=0)
        sample = pd.Series(df['country'].unique())
        sample_list[c + '_' + a] = sample_list.iloc[:, 0].isin(sample)
sample_list.to_csv('/Volumes/NJ_4TB/Final/Adaptive_Mitigative/sample_list.csv', index=False)
sample_list
# Out:
# /var/folders/m0/n45yndhx6rd3g0r9yzrc6k300000gn/T/ipykernel_37975/1033523490.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   sample_list[c + '_' + a] = sample_list.iloc[:, 0].isin(sample)
#    Country  Build_1_ExTemp  Sequester_1_ExTemp  ICT_1_ExTemp  Geo_1_ExTemp  \
# 0       KR            True                True          True          True
# 1       MX            True                True          True         False
# 2       EG            True                True          True         False
# 3       JP            True                True          True          True
# 4       NO            True                True          True          True
# 5       CA            True                True          True          True
# 6       SI            True               False          True         False
# 7       DK            True                True          True          True
# 8       TH            True                True          True         False
# 9       FI            True                True          True          True
# 10      HU            True                True          True          True
# 11      IS            True               False          True          True
# 12      IN            True                True          True          True
# 13      US            True                True          True          True
# 14      CZ            True                True          True          True
# 15      CL            True                True          True         False
# 16      PL            True                True          True          True
# 17      LV            True               False         False         False
# 18      KY            True               False          True         False
# 19      PH            True               False          True          True
# 20      DE            True                True          True          True
# 21      SG            True                True          True          True
# 22      CH            True                True          True          True
# 23      LT            True               False         False         False
# 24      CY            True               False          True          True
# 25      RU            True                True          True          True
# 26      UA            True                True          True         False
# 27      IT            True                True          True          True
# 28      AU            True                True          True          True
# 29      NZ            True                True          True          True
# 30      BE            True                True          True          True
# 31      QA            True                True         False         False
# 32      MY            True                True          True          True
# 33      BM            True               False          True         False
# 34      AT            True                True          True          True
# 35      SU            True                True          True          True
# 36      GR            True                True          True          True
# 37      MT           False               False         False         False
# 38      IE            True                True          True          True
# 39      TR            True                True          True          True
# 40      ES            True                True          True          True
# 41      NL            True                True          True          True
# 42      IL            True                True          True          True
# 43      MA            True                True         False         False
# 44      AE            True                True          True         False
# 45      CU           False               False         False         False
# 46      SE            True                True          True          True
# 47      CN            True                True          True          True
# 48      FR            True                True          True          True
# 49      LU            True                True          True         False
# 50      PA            True               False          True         False
# 51      BG            True                True          True         False
# 52      ZA            True                True          True         False
# 53      TW            True                True          True          True
# 54      AR            True                True          True          True
# 55      BR            True                True          True          True
# 56      GB            True                True          True          True
# 57      SA            True                True          True          True
#
#     Hydro_1_ExTemp  Ocean_1_ExTemp  Solar-T_1_ExTemp  PV_1_ExTemp  \
# 0             True            True              True         True
# 1             True            True              True         True
# 2             True            True              True         True
# 3             True            True              True         True
# 4             True            True              True         True
# 5             True            True              True         True
# 6             True           False              True         True
# 7             True            True              True         True
# 8             True            True              True         True
# 9             True            True              True         True
# 10            True            True              True         True
# 11            True           False              True         True
# 12            True            True              True         True
# 13            True            True              True         True
# 14            True            True              True         True
# 15            True            True              True         True
# 16            True            True              True         True
# 17            True            True              True         True
# 18            True            True             False         True
# 19            True            True              True         True
# 20            True            True              True         True
# 21            True            True              True         True
# 22            True            True              True         True
# 23            True            True              True         True
# 24            True            True              True         True
# 25            True            True              True         True
# 26            True            True              True         True
# 27            True            True              True         True
# 28            True            True              True         True
# 29            True            True              True         True
# 30            True            True              True         True
# 31            True            True             False         True
# 32            True            True              True         True
# 33            True            True              True         True
# 34            True            True              True         True
# 35            True            True              True         True
# 36            True            True              True         True
# 37           False           False             False        False
# 38            True            True              True         True
# 39            True            True              True         True
# 40            True            True              True         True
# 41            True            True              True         True
# 42            True            True              True         True
# 43            True            True              True         True
# 44            True            True              True         True
# 45            True            True              True        False
# 46            True            True              True         True
# 47            True            True              True         True
# 48            True            True              True         True
# 49            True           False              True         True
# 50            True           False              True         True
# 51            True            True              True         True
# 52            True            True              True         True
# 53            True            True              True         True
# 54            True            True              True         True
# 55            True            True              True         True
# 56            True            True              True         True
# 57            True            True              True         True
#
#     Thermal-PV_1_ExTemp  ...  Hydrogen_9_Wildfire  Processing_9_Wildfire  \
# 0                  True  ...                 True                   True
# 1                  True  ...                 True                   True
# 2                  True  ...                 True                   True
# 3                  True  ...                 True                   True
# 4                  True  ...                 True                   True
# 5                  True  ...                 True                   True
# 6                  True  ...                 True                   True
# 7                  True  ...                 True                   True
# 8                  True  ...                 True                   True
# 9                 False  ...                 True                   True
# 10                 True  ...                 True                   True
# 11                False  ...                False                  False
# 12                 True  ...                 True                   True
# 13                 True  ...                 True                   True
# 14                 True  ...                 True                   True
# 15                False  ...                False                  False
# 16                 True  ...                 True                   True
# 17                False  ...                False                  False
# 18                False  ...                False                  False
# 19                False  ...                False                  False
# 20                 True  ...                 True                   True
# 21                 True  ...                 True                   True
# 22                 True  ...                 True                   True
# 23                False  ...                False                  False
# 24                False  ...                False                  False
# 25                 True  ...                 True                   True
# 26                 True  ...                 True                   True
# 27                 True  ...                 True                   True
# 28                 True  ...                 True                   True
# 29                 True  ...                 True                   True
# 30                 True  ...                 True                   True
# 31                False  ...                False                  False
# 32                False  ...                 True                   True
# 33                False  ...                 True                   True
# 34                 True  ...                 True                   True
# 35                False  ...                 True                   True
# 36                 True  ...                 True                   True
# 37                False  ...                False                  False
# 38                 True  ...                 True                   True
# 39                 True  ...                 True                   True
# 40                 True  ...                 True                   True
# 41                 True  ...                 True                   True
# 42                 True  ...                 True                   True
# 43                 True  ...                False                  False
# 44                False  ...                False                  False
# 45                False  ...                False                  False
# 46                 True  ...                 True                   True
# 47                 True  ...                 True                   True
# 48                 True  ...                 True                   True
# 49                 True  ...                 True                   True
# 50                False  ...                 True                   True
# 51                 True  ...                 True                   True
# 52                 True  ...                 True                   True
# 53                 True  ...                 True                   True
# 54                False  ...                 True                   True
# 55                 True  ...                 True                   True
# 56                 True  ...                 True                   True
# 57                False  ...                 True                   True
#
#     Transport_9_Wildfire  Wastewater_9_Wildfire  SmrtGrds_9_Wildfire  \
# 0                   True                   True                 True
# 1                   True                   True                 True
# 2                   True                   True                 True
# 3                   True                   True                 True
# 4                   True                   True                 True
# 5                   True                   True                 True
# 6                   True                   True                 True
# 7                   True                   True                 True
# 8                   True                   True                 True
# 9                   True                   True                 True
# 10                  True                   True                 True
# 11                 False                  False                False
# 12                  True                   True                 True
# 13                  True                   True                 True
# 14                  True                   True                 True
# 15                 False                  False                False
# 16                  True                   True                 True
# 17                 False                  False                False
# 18                 False                  False                False
# 19                 False                  False                False
# 20                  True                   True                 True
# 21                  True                   True                 True
# 22                  True                   True                 True
# 23                 False                  False                False
# 24                 False                  False                False
# 25                  True                   True                 True
# 26                  True                   True                 True
# 27                  True                   True                 True
# 28                  True                   True                 True
# 29                  True                   True                 True
# 30                  True                   True                 True
# 31                 False                  False                False
# 32                  True                   True                 True
# 33                  True                   True                 True
# 34                  True                   True                 True
# 35                  True                   True                 True
# 36                  True                   True                 True
# 37                 False                  False                False
# 38                  True                   True                 True
# 39                  True                   True                 True
# 40                  True                   True                 True
# 41                  True                   True                 True
# 42                  True                   True                 True
# 43                 False                  False                False
# 44                 False                  False                False
# 45                 False                  False                False
# 46                  True                   True                 True
# 47                  True                   True                 True
# 48                  True                   True                 True
# 49                  True                   True                 True
# 50                  True                   True                 True
# 51                  True                   True                 True
# 52                  True                   True                 True
# 53                  True                   True                 True
# 54                  True                   True                 True
# 55                  True                   True                 True
# 56                  True                   True                 True
# 57                  True                   True                 True
#
#     Nuclear_9_Wildfire  Non-Fossil_9_Wildfire  Enable_9_Wildfire  \
# 0                 True                  False               True
# 1                 True                  False               True
# 2                 True                  False               True
# 3                 True                  False               True
# 4                 True                  False               True
# 5                 True                  False               True
# 6                 True                  False               True
# 7                 True                  False               True
# 8                False                  False               True
# 9                 True                   True               True
# 10                True                  False               True
# 11               False                  False              False
# 12                True                  False               True
# 13                True                   True               True
# 14                True                   True               True
# 15               False                  False              False
# 16                True                  False               True
# 17               False                  False              False
# 18               False                  False              False
# 19               False                  False              False
# 20                True                  False               True
# 21                True                  False               True
# 22                True                  False               True
# 23               False                  False              False
# 24               False                  False              False
# 25                True                  False               True
# 26                True                  False               True
# 27                True                  False               True
# 28               False                  False               True
# 29                True                  False               True
# 30                True                  False               True
# 31               False                  False              False
# 32               False                  False               True
# 33               False                  False               True
# 34                True                  False               True
# 35                True                  False               True
# 36               False                  False               True
# 37               False                  False              False
# 38               False                  False               True
# 39                True                  False               True
# 40                True                  False               True
# 41                True                  False               True
# 42                True                  False               True
# 43               False                  False              False
# 44               False                  False              False
# 45               False                  False              False
# 46                True                  False               True
# 47                True                  False               True
# 48                True                  False               True
# 49                True                  False               True
# 50               False                  False               True
# 51                True                  False               True
# 52                True                  False               True
# 53                True                  False               True
# 54                True                  False               True
# 55                True                  False               True
# 56                True                  False               True
# 57               False                  False               True
#
#     Other-1_9_Wildfire  Other-3_9_Wildfire
# 0                 True                True
# 1                 True               False
# 2                False                True
# 3                 True                True
# 4                 True                True
# 5                 True                True
# 6                False                True
# 7                 True                True
# 8                False                True
# 9                 True                True
# 10               False                True
# 11               False               False
# 12                True                True
# 13                True                True
# 14               False                True
# 15               False               False
# 16               False                True
# 17               False               False
# 18               False               False
# 19               False               False
# 20                True                True
# 21               False                True
# 22                True                True
# 23               False               False
# 24               False               False
# 25                True                True
# 26               False                True
# 27                True                True
# 28                True                True
# 29               False                True
# 30               False                True
# 31               False               False
# 32                True               False
# 33               False               False
# 34                True                True
# 35                True                True
# 36                True               False
# 37               False               False
# 38                True                True
# 39               False                True
# 40                True                True
# 41                True                True
# 42               False                True
# 43               False               False
# 44               False               False
# 45               False               False
# 46                True                True
# 47                True                True
# 48                True                True
# 49               False                True
# 50               False                True
# 51               False               False
# 52                True                True
# 53                True                True
# 54               False               False
# 55                True                True
# 56                True                True
# 57               False                True
#
# [58 rows x 181 columns]

# %%
#Filter Sample by Country
import pandas as pd
import numpy as np
Categories = ['Build','Sequester', 'ICT', 'Geo', 'Hydro', 'Ocean', 'Solar-T', 'PV', 'Thermal-PV', 'Wind', 'Combust', 'Fusion', 'Fission', 'Electric', 'Biofuel', 'Waste', 'Store- B', 'Store - C', 'Store- T', 'Store- M', 'Hydrogen', 'Processing', 'Transport', 'Wastewater', 'SmrtGrds', 'Nuclear', 'Non-Fossil', 'Enable',  'Other-1', 'Other-3']#, 'Other-5','Other-6', 'Other-4']
emdat_patsat_names = {'1_ExTemp':'Extreme temperature ', '3_Storm':'Storm', '4_Flood':'Flood', '5_Landslide':'Landslide', '7_Drought':'Drought', '9_Wildfire':'Wildfire'}
#countries = {'KR', 'JP', 'NO', 'CA', 'DK', 'HU', 'IN', 'US', 'DE', 'CH', 'RU', 'IT', 'AU', 'BE', 'AT', 'ES', 'NL', 'IL', 'SE', 'CN', 'FR', 'TW', 'BR', 'GB'}
for a in emdat_patsat_names:
    for c in Categories:
        df = pd.read_csv('/Volumes/NJ_4TB/Final/Adaptive_Mitigative/'+ c + '_'+ a + '_panel_combined.csv', skipinitialspace=True, header=0)
        df = df[df['country'].str.contains('(KR|JP|NO|CA|DK|HU|IN|US|DE|CH|RU|IT|AU|BE|AT|ES|NL|IL|SE|CN|FR|TW|BR|GB)', regex=True)]
        df.to_csv('/Volumes/NJ_4TB/Final/Adaptive_Mitigative/'+ c + '_'+ a + '_panel_24countries.csv', index=False)
# Out:
# /var/folders/m0/n45yndhx6rd3g0r9yzrc6k300000gn/T/ipykernel_37975/546920073.py:10: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df = df[df['country'].str.contains('(KR|JP|NO|CA|DK|HU|IN|US|DE|CH|RU|IT|AU|BE|AT|ES|NL|IL|SE|CN|FR|TW|BR|GB)', regex=True)]
