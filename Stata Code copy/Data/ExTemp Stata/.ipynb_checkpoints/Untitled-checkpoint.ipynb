# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('1_ExTemp_panel_combined_instruments_updated.csv')

# %%
plt.plot(np.log(df['total_damages_adj'].to_numpy() + 1))

# %%
plt.plot((df['total_damages_adj'].to_numpy()))

# %%
plt.plot(np.log(df['total_affected'].to_numpy() + 1))

# %%
plt.plot((df['total_affected'].to_numpy()))
