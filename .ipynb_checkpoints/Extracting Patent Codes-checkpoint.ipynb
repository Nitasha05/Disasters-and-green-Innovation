# %% [markdown]
# # Filtering by IPC Codes

# %%
import pandas as pd

# %% [markdown]
# ### Filtering tls209_part01 to IPC1.csv

# %%
fields = ['appln_id', 'ipc_class_symbol'] #extracting unique identifier and IPC code
df1 = pd.read_csv('/Volumes/Elements/PATSAT/tls209_part01.csv', skipinitialspace=True, usecols=fields)
print(df1.shape)
print(df1.dtypes)
print(df1.head())
df1['ipc_class_symbol'] = df1['ipc_class_symbol'].str.replace(" ","") #remove spaces
print(df1.isnull().sum()) #check for missing values

# %%
filter_list = ['F03D1', 'F03D3', 'F03D5', 'F03D7', 'F03D9', 'F03D11', 'F24J2', 'F03G6', 'E04D13/18', 'H01L27/142', 'H01L31/04','H01L31/05','H01L31/06','H01L 31/08', 'H02N6', 'F03G4', 'F03G7/04', 'F24J3 ', 'E02B9/08', 'F03B13/1','F03B13/2', 'F03G7/05', 'E02B 9', 'F03B3 ', 'F03B 7', 'F03B 13/06', 'F03B 13/07', 'F03B 13/08' 'F03B 15', 'C10L 5/40', 'C10L5/41','C10L5/42','C10L5/43', 'C10L5/44', 'C10L5/45', 'C10L5/46','C10L5/47','C10L5/48', 'F01K25/14', 'F02B43/08', 'F23G5/46', 'C10L1', 'B09B1', 'F01K27', 'F23G5']
df1f = df1[df1.ipc_class_symbol.isin(filter_list)]
df1f.to_csv('IPC1',index=False)

# %% [markdown]
# ###  Filtering tls209_part02 to IPC2.csv

# %%
fields = ['appln_id', 'ipc_class_symbol']
filter_list = ['F03D1', 'F03D3', 'F03D5', 'F03D7', 'F03D9', 'F03D11', 'F24J2', 'F03G6', 'E04D13/18', 'H01L27/142', 'H01L31/04','H01L31/05','H01L31/06','H01L 31/08', 'H02N6', 'F03G4', 'F03G7/04', 'F24J3 ', 'E02B9/08', 'F03B13/1','F03B13/2', 'F03G7/05', 'E02B 9', 'F03B3 ', 'F03B 7', 'F03B 13/06', 'F03B 13/07', 'F03B 13/08' 'F03B 15', 'C10L 5/40', 'C10L5/41','C10L5/42','C10L5/43', 'C10L5/44', 'C10L5/45', 'C10L5/46','C10L5/47','C10L5/48', 'F01K25/14', 'F02B43/08', 'F23G5/46', 'C10L1', 'B09B1', 'F01K27', 'F23G5']
df2 = pd.read_csv('/Volumes/Elements/PATSAT/tls209_part02.csv', skipinitialspace=True, usecols=fields)
df2['ipc_class_symbol'] = df2['ipc_class_symbol'].str.replace(" ","") #remove spaces
print(df2.isnull().sum()) #check for missing values
print(df2.shape)
print(df2.dtypes)
print(df2.head())

# %%
df2f = df2[df2.ipc_class_symbol.isin(filter_list)]
df2f.to_csv('IPC2',index=False)

# %% [markdown]
# # Filtering by CPC codes

# %% [markdown]
# ### Filtering to CPC1.csv

# %%
fields = ['appln_id', 'cpc_class_symbol']
filter_list = ['Y02A','Y02B','Y02C','Y02D','Y02E','Y02P','Y02T','Y02W','Y04S','Y10S','Y10T']
df3 = pd.read_csv('/Volumes/Elements/PATSAT/tls224_part01.csv',skipinitialspace=True, chunksize=5000, header=0,usecols=fields)
for chunk in df3:
    chunk['cpc_class_symbol'] = chunk['cpc_class_symbol'].str.replace(" ","") 
#     chunk[1] = chunk[1].str.replace(" ","") #remove spaces
#     #df3 = df3[df3.cpc_class_symbol.isin(filter_list)]
#     chunk.to_csv('df3.csv',index = False, header = False)
#     print(df3.shape)
#     print(df3.dtypes)
#     print(df3.isnull().sum()) #check for missing values
#     print(df3.head())
# Out:
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ['cpc_class_symbol']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1347a8a7281a> in <module>
#       2 filter_list = ['Y02A','Y02B','Y02C','Y02D','Y02E','Y02P','Y02T','Y02W','Y04S','Y10S','Y10T']
#       3 df3 = pd.read_csv('/Volumes/Elements/PATSAT/tls224_part01.csv',skipinitialspace=True, chunksize=5000, header=0,usecols=fields)
# ----> 4 for chunk in df3:
#       5     print(chunk.columns.values)
#       6     chunk['cpc_class_symbol'] = chunk['cpc_class_symbol'].str.replace(" ","")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1126     def __next__(self):
#    1127         try:
# -> 1128             return self.get_chunk()
#    1129         except StopIteration:
#    1130             self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1186                 raise StopIteration
#    1187             size = min(size, self.nrows - self._currow)
# -> 1188         return self.read(nrows=size)
#    1189
#    1190
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._concatenate_chunks()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     676
#     677
# --> 678 def is_categorical_dtype(arr_or_dtype):
#     679     """
#     680     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Filtering to CPC2.csv

# %%
fields = ['appln_id', 'cpc_class_symbol']
df4 = pd.read_csv('/Volumes/Elements/PATSAT/tls224_part02.csv', skipinitialspace=True, usecols=fields)
print(df4.shape)
print(df4.dtypes)
df4['cpc_class_symbol'] = df4['cpc_class_symbol'].str.replace(" ","") #remove spaces
print(df4.isnull().sum()) #check for missing values
print(df4.head())

# %%
filter_list = ['Y02A','Y02B','Y02C','Y02D','Y02E','Y02P','Y02T','Y02W','Y04S','Y10S','Y10T']
df4f = df4[df4.cpc_class_symbol.isin(filter_list)]
df4f.to_csv('CPC2',index=False)
